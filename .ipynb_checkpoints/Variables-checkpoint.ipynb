# %% [markdown]
# # Variables
# ## Vamos a
# ### -Trabajar con variables de python
# ## Vamos a:
# ### -Realizar operaciones aritméticas
# ### -Crear variables en notebook
# ### -Diferenciar distintos tipos de datos

# %% [markdown]
# # 1.-Comentarios

# %%
#Para colocar un comentario es necesario colocar el numeral, gato o hashtag (#)
#lo que se coloque posterior al numeral(#) no se ejecuta
1+1-1*(1+1-1)/1+1*(-1)
# Out:
# 0.0

# %% [markdown]
# # 2.-Variables
#
# Sirven para guardar operaciones aritméticas, reutilizar código, estructurar y abstraer el análisis.
#
# La estructura para crear una variable es:
# ### -nombre_variable = Contenido
# ### -edad = 30

# %%
#ejercicio: agreva valor a las variables
mango = 10
manzana = 5
aguacate =15

(2*aguacate)+(4*manzana)+(1.5*mango)
# Out:
# 65.0

# %% [markdown]
# ## Tipos de variable
# ### Existen diferentes tipos de variables entre los que destacan:
# #### -Enteros   [1,2,3,4,5...]
# #### -Voleanos  [1.1,1.2,1.3,1.4,1.5 ....]
# #### -Texto     ["América","México","EDOMEX","Almoloya","Mayorazgo"]
# #### -Booleanos [True/False]
# ### Estos no son los únicos, pero son los más comunes

# %%
#Para conocer el tipo de variable de un tipo de dato se usa la función type()
type(1)
# Out:
# int

# %%
type(3.1416)
# Out:
# float

# %%
type('Islandia')
# Out:
# str

# %%
type(True)
# Out:
# bool
