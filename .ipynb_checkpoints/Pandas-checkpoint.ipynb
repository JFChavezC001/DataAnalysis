# %% [markdown]
# # Pandas

# %% [markdown]
# ### -Es un paquete que ayuda a trabajar con datos multidimensionales
# ### -Significa Panes DataSets
# ### -Podemos manipular tablas de datos de diferentes tipos en distintos DataFrames

# %%
#Lo primero que haremos sera c
